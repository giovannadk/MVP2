# %% [markdown]
# <a href="https://colab.research.google.com/github/giovannadk/API-1-semestre-LOG/blob/main/Api_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
caminho_in = '/content/drive/My Drive/Data/'
caminho_out = '/content/drive/My Drive/Data/'

# %%
file1 = caminho_in + 'EXP_2023_MUN.csv'
with open(file1, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Linha 1: "CO_ANO";"CO_MES";"SH4";"CO_PAIS";"SG_UF_MUN";"CO_MUN";"KG_LIQUIDO";"VL_FOB"
#
# Linha 2: "2023";"10";"2209";"127";"BA";"2919553";36;53
#
# Linha 3: "2023";"11";"4009";"493";"SP";"3456701";473;14008
#
# Linha 4: "2023";"11";"8536";"365";"SP";"3438709";2;181
#
# Linha 5: "2023";"08";"8512";"063";"RJ";"3304201";15627;239105

# %%
df1 = pd.read_csv(file1, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1121352 entries, 0 to 1121351
# Data columns (total 8 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   CO_ANO      1121352 non-null  int64
#  1   CO_MES      1121352 non-null  int64
#  2   SH4         1121352 non-null  int64
#  3   CO_PAIS     1121352 non-null  int64
#  4   SG_UF_MUN   1121352 non-null  object
#  5   CO_MUN      1121352 non-null  int64
#  6   KG_LIQUIDO  1121352 non-null  int64
#  7   VL_FOB      1121352 non-null  int64
# dtypes: int64(7), object(1)
# memory usage: 68.4+ MB

# %%
file2 = caminho_in + 'EXP_2024_MUN.csv'
with open(file2, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Linha 1: "CO_ANO";"CO_MES";"SH4";"CO_PAIS";"SG_UF_MUN";"CO_MUN";"KG_LIQUIDO";"VL_FOB"
#
# Linha 2: "2024";"02";"8708";"158";"MG";"3106705";3346;97359
#
# Linha 3: "2024";"09";"1516";"845";"SP";"3425904";349090;541361
#
# Linha 4: "2024";"07";"8536";"158";"SC";"4208906";1711;20706
#
# Linha 5: "2024";"08";"4010";"063";"SP";"3452205";4586;176026

# %%
df2 = pd.read_csv(file2, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1144828 entries, 0 to 1144827
# Data columns (total 8 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   CO_ANO      1144828 non-null  int64
#  1   CO_MES      1144828 non-null  int64
#  2   SH4         1144828 non-null  int64
#  3   CO_PAIS     1144828 non-null  int64
#  4   SG_UF_MUN   1144828 non-null  object
#  5   CO_MUN      1144828 non-null  int64
#  6   KG_LIQUIDO  1144828 non-null  int64
#  7   VL_FOB      1144828 non-null  int64
# dtypes: int64(7), object(1)
# memory usage: 69.9+ MB

# %%
csv_final = [file1, file2]
EXP_2324 = pd.DataFrame()
for csv_final in csv_final:
    df = pd.read_csv(csv_final, sep = ';')
    EXP_2324 = pd.concat([EXP_2324, df], ignore_index=True)
EXP_2324.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2266180 entries, 0 to 2266179
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      int64
#  1   CO_MES      int64
#  2   SH4         int64
#  3   CO_PAIS     int64
#  4   SG_UF_MUN   object
#  5   CO_MUN      int64
#  6   KG_LIQUIDO  int64
#  7   VL_FOB      int64
# dtypes: int64(7), object(1)
# memory usage: 138.3+ MB

# %%
EXP_SP.head(5)

# %%
EXP_SP.tail(5)

# %%
colunas_interesse = ['CO_ANO','CO_MES','SH4',
                     'CO_PAIS','SG_UF_MUN','CO_MUN',
                     'KG_LIQUIDO','VL_FOB']

# %%
EXP = EXP_2324.dropna(subset=colunas_interesse)
EXP.info()

# %%
EXP_SP = EXP[EXP['SG_UF_MUN'] == 'SP']
EXP_SP.tail(5)

# %%
EXP_SP['CO_DATA'] = EXP_SP['CO_MES'].astype(str).str.zfill(2) + '/' + EXP_SP['CO_ANO'].astype(str)

# %%
colunas_interesse1 = ['CO_DATA','SH4',
                     'CO_PAIS','SG_UF_MUN','CO_MUN',
                     'KG_LIQUIDO','VL_FOB']
EXP_SP = EXP_SP[colunas_interesse1]
EXP_SP.head(5)
# Out:
#          CO_DATA   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO  VL_FOB
# 2266171  02/2024  8442      576        SP  3438709        3647  190732
# 2266174  03/2024  8526      169        SP  3409205           0      72
# 2266175  08/2024  6206       63        SP  3405500           3      79
# 2266178  02/2024  8504      589        SP  3448906           0    2390
# 2266179  11/2024   406      776        SP  3448500           4      72

# %%
EXP_SP.to_csv(caminho_out + 'EXP_SP.csv', sep=';', index=False, encoding = 'UTF-8', decimal=",")

# %%
file3 = caminho_in + 'MUN_SP1.csv'
with open(file3, 'r', encoding='latin-1') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Linha 1: CO_MUN_GEO;NO_MUN;NO_MUN_MIN;SG_UF
#
# Linha 2: 3446900;SANTA LUCIA;Santa Lúcia;SP
#
# Linha 3: 3447007;SANTA MARIA DA SERRA;Santa Maria da Serra;SP
#
# Linha 4: 3447106;SANTA MERCEDES;Santa Mercedes;SP
#
# Linha 5: 3447205;SANTANA DA PONTE PENSA;Santana da Ponte Pensa;SP

# %%
df3 = pd.read_csv(file3, low_memory=False, sep=';', encoding = 'latin-1', decimal =",")
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CO_MUN_GEO  645 non-null    int64
#  1   NO_MUN      645 non-null    object
#  2   NO_MUN_MIN  645 non-null    object
#  3   SG_UF       645 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 20.3+ KB

# %%
colunas_interesse5 = ['CO_MUN_GEO', 'NO_MUN']
MUN_SP1 = df3[colunas_interesse5]
MUN_SP1.head(5)
# Out:
#    CO_MUN_GEO                  NO_MUN
# 0     3446900             SANTA LUCIA
# 1     3447007    SANTA MARIA DA SERRA
# 2     3447106          SANTA MERCEDES
# 3     3447205  SANTANA DA PONTE PENSA
# 4     3447304     SANTANA DE PARNAIBA

# %%
MUN_SP1 = df3[df3['SG_UF'] == 'SP']
MUN_SP1.head(5)
# Out:
#       CO_MUN_GEO                  NO_MUN              NO_MUN_MIN SG_UF
# 1130     3446900             SANTA LUCIA             Santa Lúcia    SP
# 1131     3447007    SANTA MARIA DA SERRA    Santa Maria da Serra    SP
# 1132     3447106          SANTA MERCEDES          Santa Mercedes    SP
# 1133     3447205  SANTANA DA PONTE PENSA  Santana da Ponte Pensa    SP
# 1134     3447304     SANTANA DE PARNAIBA     Santana de Parnaíba    SP

# %%
MUN_SP1.to_csv(caminho_out + 'MUN_SP1.csv', sep=';', index=False, encoding = 'latin-1', decimal=",")

# %%
file4 = caminho_in + 'SH4s.csv'
with open(file4, 'r', encoding='latin-1') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Linha 1: CO_SH4;NO_SH4_POR;NO_SH4_ING
#
# Linha 2: 101;Cavalos, asininos e muares, vivos;Live horses, asses, mules and hinnies
#
# Linha 3: 101;Cavalos, asininos e muares, vivos;Live horses, asses, mules and hinnies
#
# Linha 4: 101;Cavalos, asininos e muares, vivos;Live horses, asses, mules and hinnies
#
# Linha 5: 101;Cavalos, asininos e muares, vivos;Live horses, asses, mules and hinnies

# %%
df4 = pd.read_csv(file4, low_memory=False, sep=';', encoding = 'latin-1', decimal =",")
colunas_interesse3 = ['CO_SH4', 'NO_SH4_POR']
SH4s = df4[colunas_interesse3]
SH4s.tail(5)
# Out:
#       CO_SH4                                         NO_SH4_POR
# 6604    9997                                 Mercadorias doadas
# 6605    9998  Consumo de bordo (combustíveis e lubrificantes...
# 6606    9998  Consumo de bordo (combustíveis e lubrificantes...
# 6607    9999  Consumo de bordo (exceto combustíveis e lubrif...
# 6608    9999  Consumo de bordo (exceto combustíveis e lubrif...

# %%
SH4s.to_csv(caminho_out + 'SH4s.csv', sep=';', index=False, encoding = 'latin-1', decimal=",")

# %%
file1 = caminho_in + 'PAIS.csv'
with open(file1, 'r', encoding='latin-1') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Linha 1: "CO_PAIS";"CO_PAIS_ISON3";"CO_PAIS_ISOA3";"NO_PAIS";"NO_PAIS_ING";"NO_PAIS_ESP"
#
# Linha 2: "000";"898";"ZZZ";"Não Definido";"Not defined";"No definido"
#
# Linha 3: "013";"004";"AFG";"Afeganistão";"Afghanistan";"Afganistan"
#
# Linha 4: "015";"248";"ALA";"Aland, Ilhas";"Aland Islands";"Alans, Islas"
#
# Linha 5: "017";"008";"ALB";"Albânia";"Albania";"Albania"

# %%
df1 = pd.read_csv(file1, low_memory=False, sep=';', encoding = 'latin-1', decimal =",")

# %%
colunas_interesse = ['CO_PAIS', 'CO_PAIS_ISON3', 'NO_PAIS']
PAISES = df1[colunas_interesse]
PAISES.head(5)
# Out:
#    CO_PAIS  CO_PAIS_ISON3                 NO_PAIS
# 0        0            898            Não Definido
# 1       13              4             Afeganistão
# 2       15            248            Aland, Ilhas
# 3       17              8                 Albânia
# 4       20            724  Alboran-Perejil, Ilhas

# %%
PAISES.to_csv(caminho_out + 'PAISES.csv', sep=';', index=False, encoding = 'latin-1', decimal=",")

# %%
file1 = caminho_in + 'EXP_SP.csv'
with open(file1, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Linha 1: CO_DATA;SH4;CO_PAIS;SG_UF_MUN;CO_MUN;KG_LIQUIDO;VL_FOB
#
# Linha 2: 11/2023;4009;493;SP;3456701;473;14008
#
# Linha 3: 11/2023;8536;365;SP;3438709;2;181
#
# Linha 4: 06/2023;8421;63;SP;3450308;6002;131714
#
# Linha 5: 04/2023;9403;586;SP;3447304;70;264

# %%
df1 = pd.read_csv(file1, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

# %%
duplicados = df1.duplicated(subset=['CO_MUN_GEO'], keep=False)
if duplicados.any():
    print("Existem valores duplicados.")
    print(df1[duplicados])
else:
    print("Coluna com valores unicos.")
# Out:
# Coluna com valores unicos.

# %%
df1_sem_duplicatas = df1.drop_duplicates(keep='first')
SH4s = df1_sem_duplicatas
SH4s.head(10)
# Out:
#     CO_SH4                                         NO_SH4_POR
# 0      101                  Cavalos, asininos e muares, vivos
# 8      102                    Animais vivos da espécie bovina
# 14     103                     Animais vivos da espécie suína
# 17     104         Animais vivos das espécies ovina e caprina
# 19     105  Galos, galinhas, patos, gansos, perus, peruas ...
# 29     106                               Outros animais vivos
# 43     201  Carnes de animais da espécie bovina, frescas o...
# 46     202    Carnes de animais da espécie bovina, congeladas
# 49     203  Carnes de animais da espécie suína, frescas, r...
# 55     204  Carnes de animais das espécies ovina ou caprin...

# %%
SH4s.to_csv(caminho_out + 'SH4s.csv', sep=';', index=False, encoding = 'latin-1', decimal=",")

# %%
file2 = caminho_in + 'SH4s.csv'
with open(file2, 'r', encoding='latin-1') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
df2 = pd.read_csv(file2, low_memory=False, sep=';', encoding = 'latin-1', decimal =",")
# Out:
# Linha 1: CO_SH4;NO_SH4_POR
#
# Linha 2: 101;Cavalos, asininos e muares, vivos
#
# Linha 3: 102;Animais vivos da espécie bovina
#
# Linha 4: 103;Animais vivos da espécie suína
#
# Linha 5: 104;Animais vivos das espécies ovina e caprina

# %%
mapeamento_sh4 = dict(zip(df2['CO_SH4'], df2['NO_SH4_POR']))
df1['NO_SH4_POR'] = df1['SH4'].map(mapeamento_sh4)
df1.head(15)
# Out:
#     CO_DATA   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO   VL_FOB  \
# 0   11/2023  4009      493        SP  3456701         473    14008
# 1   11/2023  8536      365        SP  3438709           2      181
# 2   06/2023  8421       63        SP  3450308        6002   131714
# 3   04/2023  9403      586        SP  3447304          70      264
# 4   06/2023  8419      158        SP  3409502          44     4456
# 5   09/2023  3305      820        SP  3456701         372     8184
# 6   06/2023  7326      239        SP  3440606           0        6
# 7   12/2023  8471      249        SP  3450308        1473  4741262
# 8   09/2023  3305       59        SP  3450308          60      604
# 9   01/2023  4820      158        SP  3452403         116     6344
# 10  10/2023  9032      845        SP  3452403           2     1803
# 11  08/2023  8409      158        SP  3452205         287    15884
# 12  08/2023  8708      847        SP  3413801        1794    53398
# ...

# %%
file3 = caminho_in + 'MUN_SP1.csv'
with open(file3, 'r', encoding='latin-1') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
df3 = pd.read_csv(file3, low_memory=False, sep=';', encoding = 'latin-1', decimal =",")
# Out:
# Linha 1: CO_MUN_GEO;NO_MUN
#
# Linha 2: 3446900;SANTA LUCIA
#
# Linha 3: 3447007;SANTA MARIA DA SERRA
#
# Linha 4: 3447106;SANTA MERCEDES
#
# Linha 5: 3447205;SANTANA DA PONTE PENSA

# %%
mapeamento_mun = dict(zip(df3['CO_MUN_GEO'], df3['NO_MUN']))
df1['NO_MUN'] = df1['CO_MUN'].map(mapeamento_mun)
df1.head(10)
# Out:
#    CO_DATA   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO   VL_FOB  \
# 0  11/2023  4009      493        SP  3456701         473    14008
# 1  11/2023  8536      365        SP  3438709           2      181
# 2  06/2023  8421       63        SP  3450308        6002   131714
# 3  04/2023  9403      586        SP  3447304          70      264
# 4  06/2023  8419      158        SP  3409502          44     4456
# 5  09/2023  3305      820        SP  3456701         372     8184
# 6  06/2023  7326      239        SP  3440606           0        6
# 7  12/2023  8471      249        SP  3450308        1473  4741262
# 8  09/2023  3305       59        SP  3450308          60      604
# 9  01/2023  4820      158        SP  3452403         116     6344
#
#                                           NO_SH4_POR               NO_MUN
# 0  Tubos de borracha vulcanizada não endurecida, ...              VINHEDO
# 1  Aparelhos para interrupção, seccionamento, pro...           PIRACICABA
# ...

# %%
file4 = caminho_in + 'PAISES.csv'
with open(file4, 'r', encoding='latin-1') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
df4 = pd.read_csv(file4, low_memory=False, sep=';', encoding = 'latin-1', decimal =",")
# Out:
# Linha 1: CO_PAIS;CO_PAIS_ISON3;NO_PAIS
#
# Linha 2: 0;898;Não Definido
#
# Linha 3: 13;4;Afeganistão
#
# Linha 4: 15;248;Aland, Ilhas
#
# Linha 5: 17;8;Albânia

# %%
mapeamento_mun = dict(zip(df4['CO_PAIS'], df4['NO_PAIS']))
df1['NO_PAIS'] = df1['CO_PAIS'].map(mapeamento_mun)
df1.head(5)
# Out:
#    CO_DATA   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO  VL_FOB  \
# 0  11/2023  4009      493        SP  3456701         473   14008
# 1  11/2023  8536      365        SP  3438709           2     181
# 2  06/2023  8421       63        SP  3450308        6002  131714
# 3  04/2023  9403      586        SP  3447304          70     264
# 4  06/2023  8419      158        SP  3409502          44    4456
#
#                                           NO_SH4_POR               NO_MUN  \
# 0  Tubos de borracha vulcanizada não endurecida, ...              VINHEDO
# 1  Aparelhos para interrupção, seccionamento, pro...           PIRACICABA
# 2  Centrifugadores, incluídos os secadores centrí...            SAO PAULO
# 3                        Outros móveis e suas partes  SANTANA DE PARNAIBA
# 4  Aparelhos e dispositivos, mesmo aquecidos elec...             CAMPINAS
#
#      NO_PAIS
# 0     México
# 1  Indonésia
# 2  Argentina
# 3   Paraguai
# 4      Chile

# %%
colunas_interesse = ['CO_DATA', 'SG_UF_MUN', 'KG_LIQUIDO', 'VL_FOB',
                     'NO_SH4_POR', 'NO_MUN', 'NO_PAIS']
EXP_SP_FINAL = df1[colunas_interesse]
EXP_SP_FINAL.tail(5)
# Out:
#         CO_DATA SG_UF_MUN  KG_LIQUIDO  VL_FOB  \
# 951552  02/2024        SP        3647  190732
# 951553  03/2024        SP           0      72
# 951554  08/2024        SP           3      79
# 951555  02/2024        SP           0    2390
# 951556  11/2024        SP           4      72
#
#                                                NO_SH4_POR      NO_MUN  \
# 951552  Máquinas, aparelhos e material (exceto as máqu...  PIRACICABA
# 951553  Aparelhos de radiodetecção e de radiossondagem...     CAJAMAR
# 951554  Camiseiros, blusas, blusas-camiseiros, de uso ...    BARRETOS
# 951555  Transformadores elétricos, conversores elétric...  SAO CARLOS
# 951556                                Queijos e requeijão      SANTOS
#
#           NO_PAIS
# 951552  Paquistão
# 951553   Colômbia
# 951554  Argentina
# 951555       Peru
# 951556  Tailândia

# %%
EXP_SP_FINAL.to_csv(caminho_out + 'EXP_SP_FINAL.csv', sep=';', index=False, encoding = 'UTF-8', decimal=",")

# %%
file1 = caminho_in + 'EXP_SP_FINAL.csv'
with open(file1, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Linha 1: CO_DATA;SG_UF_MUN;KG_LIQUIDO;VL_FOB;NO_SH4_POR;NO_MUN;NO_PAIS
#
# Linha 2: 11/2023;SP;473;14008;Tubos de borracha vulcanizada não endurecida, mesmo providos dos respectivos acessórios (por exemplo: juntas, cotovelos, flanges, uniões);VINHEDO;México
#
# Linha 3: 11/2023;SP;2;181;Aparelhos para interrupção, seccionamento, protecção, derivação, ligação ou conexão de circuitos elétricos (por exemplo: interruptores, comutadores, relés, corta-circuitos, eliminadores de onda, tomadas de corrente, machos e fêmeas, suportes para lâmpada;PIRACICABA;Indonésia
#
# Linha 4: 06/2023;SP;6002;131714;Centrifugadores, incluídos os secadores centrífugos, aparelhos para filtrar ou depurar líquidos ou gases;SAO PAULO;Argentina
#
# Linha 5: 04/2023;SP;70;264;Outros móveis e suas partes;SANTANA DE PARNAIBA;Paraguai

# %%
df1 = pd.read_csv(file1, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

# %%
zeros_kg_liquido = df1['KG_LIQUIDO'][df1['KG_LIQUIDO'] == 0].count()
zeros_vl_fob = df1['VL_FOB'][df1['VL_FOB'] == 0].count()
print(f"Zeros na coluna KG_LIQUIDO: {zeros_kg_liquido}")
print(f"Zeros na coluna VL_FOB: {zeros_vl_fob}")
# Out:
# Zeros na coluna KG_LIQUIDO: 88158
# Zeros na coluna VL_FOB: 2453

# %%
df1['data_23'] = df1['CO_DATA'].where(df1['CO_DATA'].str.contains('/2023'))
df1['data_24'] = df1['CO_DATA'].where(df1['CO_DATA'].str.contains('/2024'))
EXP_SP_FINAL = df1
EXP_SP_FINAL.head(10)
# Out:
#    CO_DATA SG_UF_MUN  KG_LIQUIDO   VL_FOB  \
# 0  11/2023        SP         473    14008
# 1  11/2023        SP           2      181
# 2  06/2023        SP        6002   131714
# 3  04/2023        SP          70      264
# 4  06/2023        SP          44     4456
# 5  09/2023        SP         372     8184
# 6  06/2023        SP           0        6
# 7  12/2023        SP        1473  4741262
# 8  09/2023        SP          60      604
# 9  01/2023        SP         116     6344
#
#                                           NO_SH4_POR               NO_MUN  \
# 0  Tubos de borracha vulcanizada não endurecida, ...              VINHEDO
# 1  Aparelhos para interrupção, seccionamento, pro...           PIRACICABA
# 2  Centrifugadores, incluídos os secadores centrí...            SAO PAULO
# 3                        Outros móveis e suas partes  SANTANA DE PARNAIBA
# 4  Aparelhos e dispositivos, mesmo aquecidos elec...             CAMPINAS
# ...

# %%
colunas_interesse = ['data_23', 'NO_MUN', 'NO_PAIS',
                     'KG_LIQUIDO', 'VL_FOB', 'NO_SH4_POR',]
EXP_2023 = EXP_SP_FINAL[colunas_interesse]
EXP_2023.tail(5)
# Out:
#        data_23      NO_MUN    NO_PAIS  KG_LIQUIDO  VL_FOB  \
# 951552     NaN  PIRACICABA  Paquistão        3647  190732
# 951553     NaN     CAJAMAR   Colômbia           0      72
# 951554     NaN    BARRETOS  Argentina           3      79
# 951555     NaN  SAO CARLOS       Peru           0    2390
# 951556     NaN      SANTOS  Tailândia           4      72
#
#                                                NO_SH4_POR
# 951552  Máquinas, aparelhos e material (exceto as máqu...
# 951553  Aparelhos de radiodetecção e de radiossondagem...
# 951554  Camiseiros, blusas, blusas-camiseiros, de uso ...
# 951555  Transformadores elétricos, conversores elétric...
# 951556                                Queijos e requeijão

# %%
EXP_2023 = EXP_2023.dropna(subset=['data_23'])
EXP_2023.tail(5)
EXP_2023.to_csv(caminho_out + 'EXP_SP_2023.csv', sep=';', index=False, encoding = 'UTF-8', decimal=",")

# %%
colunas_interesse1 = ['data_24', 'NO_MUN', 'NO_PAIS',
                     'KG_LIQUIDO', 'VL_FOB', 'NO_SH4_POR',]
EXP_2024 = EXP_SP_FINAL[colunas_interesse1]
EXP_2024 = EXP_2024.dropna(subset=['data_24'])
EXP_2024.tail(5)
# Out:
#         data_24      NO_MUN    NO_PAIS  KG_LIQUIDO  VL_FOB  \
# 951552  02/2024  PIRACICABA  Paquistão        3647  190732
# 951553  03/2024     CAJAMAR   Colômbia           0      72
# 951554  08/2024    BARRETOS  Argentina           3      79
# 951555  02/2024  SAO CARLOS       Peru           0    2390
# 951556  11/2024      SANTOS  Tailândia           4      72
#
#                                                NO_SH4_POR
# 951552  Máquinas, aparelhos e material (exceto as máqu...
# 951553  Aparelhos de radiodetecção e de radiossondagem...
# 951554  Camiseiros, blusas, blusas-camiseiros, de uso ...
# 951555  Transformadores elétricos, conversores elétric...
# 951556                                Queijos e requeijão

# %%
EXP_2024.to_csv(caminho_out + 'EXP_SP_2024.csv', sep=';', index=False, encoding = 'UTF-8', decimal=",")

# %%
EXP_SP_FINAL.tail(5)
# Out:
#         MES_ANO ESTADO  KG_LIQUIDO  VL_FOB  \
# 951550  03/2024     SP      110571  689882
# 951551  08/2024     SP          11     104
# 951552  02/2024     SP        3647  190732
# 951554  08/2024     SP           3      79
# 951556  11/2024     SP           4      72
#
#                                                   PRODUTO   MUNICIPIO  \
# 951550    Carnes de animais da espécie bovina, congeladas   ANDRADINA
# 951551  Café, mesmo torrado ou descafeinado; cascas e ...      SANTOS
# 951552  Máquinas, aparelhos e material (exceto as máqu...  PIRACICABA
# 951554  Camiseiros, blusas, blusas-camiseiros, de uso ...    BARRETOS
# 951556                                Queijos e requeijão      SANTOS
#
#               PAIS_EXP data_23  data_24   VL_A
# 951550  Arábia Saudita     NaN  03/2024   6,24
# 951551          Grécia     NaN  08/2024   9,45
# 951552       Paquistão     NaN  02/2024   52,3
# 951554       Argentina     NaN  08/2024  26,33
# ...

# %%
EXP_SP_FINAL['VL_A'] = EXP_SP_FINAL['VL_FOB'] / EXP_SP_FINAL['KG_LIQUIDO']
EXP_SP_FINAL['VL_A'] = EXP_SP_FINAL['VL_A'].round(2)
EXP_SP_FINAL['VL_A'] = EXP_SP_FINAL['VL_A'].astype(str).str.replace('.', ',')

# %%
novo_nome = {'CO_DATA': 'MES_ANO',
             'SG_UF_MUN': 'ESTADO',
             'NO_SH4_POR': 'PRODUTO',
             'NO_MUN': 'MUNICIPIO',
             'NO_PAIS': 'PAIS_EXP',}
EXP_SP_FINAL = EXP_SP_FINAL.rename(columns=novo_nome)

# %%
EXP_SP_FINAL.to_csv(caminho_out + 'EXP_FINAL.csv', sep=';', index=False, encoding = 'UTF-8', decimal=",")

# %%
EXP_SP_FINAL = EXP_SP_FINAL.loc[(EXP_SP_FINAL['KG_LIQUIDO'] != 0) & (EXP_SP_FINAL['VL_FOB'] != 0)]

# %%
EXP_SP_FINAL.to_csv(caminho_out + 'EXP_FINAL_N0.csv', sep=';', index=False, encoding = 'UTF-8', decimal=",")

# %%
file1 = caminho_in + 'EXP_FINAL_N0.csv'
with open(file1, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
df1 = pd.read_csv(file1, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")
# Out:
# Linha 1: MES_ANO;ESTADO;KG_LIQUIDO;VL_FOB;PRODUTO;MUNICIPIO;PAIS_EXP;data_23;data_24;VL_A
#
# Linha 2: 11/2023;SP;473;14008;Tubos de borracha vulcanizada não endurecida, mesmo providos dos respectivos acessórios (por exemplo: juntas, cotovelos, flanges, uniões);VINHEDO;México;11/2023;;29,62
#
# Linha 3: 11/2023;SP;2;181;Aparelhos para interrupção, seccionamento, protecção, derivação, ligação ou conexão de circuitos elétricos (por exemplo: interruptores, comutadores, relés, corta-circuitos, eliminadores de onda, tomadas de corrente, machos e fêmeas, suportes para lâmpada;PIRACICABA;Indonésia;11/2023;;90,5
#
# Linha 4: 06/2023;SP;6002;131714;Centrifugadores, incluídos os secadores centrífugos, aparelhos para filtrar ou depurar líquidos ou gases;SAO PAULO;Argentina;06/2023;;21,95
#
# Linha 5: 04/2023;SP;70;264;Outros móveis e suas partes;SANTANA DE PARNAIBA;Paraguai;04/2023;;3,77

# %%
EXP_FINAL_N0 = df1
EXP_FINAL_N0.tail(30)
# Out:
#         MES_ANO ESTADO  KG_LIQUIDO  VL_FOB  \
# 862760  09/2024     SP           1       9
# 862761  06/2024     SP           3    8964
# 862762  10/2024     SP          28    1229
# 862763  08/2024     SP          22     160
# 862764  11/2024     SP        1679    6442
# 862765  08/2024     SP          13     543
# 862766  01/2024     SP           1      11
# 862767  03/2024     SP           1     449
# 862768  07/2024     SP       40000   53143
# 862769  12/2024     SP           4     368
# 862770  10/2024     SP          54    5333
# 862771  05/2024     SP          21    2451
# 862772  08/2024     SP          13     544
# 862773  03/2024     SP           1     135
# 862774  10/2024     SP       30438  109620
# 862775  02/2024     SP           1    1552
# 862776  01/2024     SP        3900   20046
# 862777  05/2024     SP         180    3604
# 862778  07/2024     SP          12     125
# 862779  12/2024     SP          18      65
# 862780  09/2024     SP     1392141  893015
# ...
